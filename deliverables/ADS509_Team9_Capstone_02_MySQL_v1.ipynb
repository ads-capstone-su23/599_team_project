# %% [markdown]
# # 509 Final Project

# %% [markdown]
# This notebook queries the URLs from the MySQL table, scrapes the HTML article contents, then inserts it into a pandas dataframe. The scraped data is then persisted in two ways: 1) The HTML content is written it back to another column in the MySQL table; 2) A copy of the full DF is written to a CSV file for further processing (i.e., preprocessing).

# %% [markdown]
# ## Globally import libraries

# %% [markdown]
# Libraries needed mostly pertain to MySQL database connection and dataframe manipulation.

# %%
import numpy as np
import pandas as pd
import pymysql as mysql
import matplotlib.pyplot as plt
import os
import shutil
import re
import logging
import time
import zipfile
import requests
from bs4 import BeautifulSoup
import datetime as dt
import re
import regex as rex
from collections import defaultdict, Counter
import random
import json

# Set pandas global options
pd.options.display.max_rows = 17

# %% [markdown]
# ## Initiate MySQL connection

# %% [markdown]
# Open connection to existing MySQL schema and table. Pull masked user and password from environment variable.

# %%
'''Set local environment variables to hide user name & password citation:
https://www.geeksforgeeks.org/how-to-hide-sensitive-credentials-using-python/
'''
user_name = os.environ['MySQLUSRAC']
user_pass = os.environ['MySQLPWDAC']

# Instantiate connection
db_conn = mysql.connect(host='localhost',
                        port=int(3306),
                        user=user_name,
                        passwd=user_pass,
                        db='599_capstone')

# Create a cursor object
cursor = db_conn.cursor()

# %% [markdown]
# Display schema tables to ensure the connection was successful.

# %%
tbl_names = pd.read_sql('SHOW TABLES', db_conn)

display(tbl_names)
print(type(tbl_names))
# Out:
#   Tables_in_599_capstone
# 0               nar_temp
# 1          news_articles
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Use pandas to select all articles from the MySQL database

# %%
slct_tbl_full_df02 = pd.read_sql(
                                '''
                                SELECT * FROM news_articles
                                ''',
                                db_conn)

# %% [markdown]
# Establish working directories for saving dataframes as CSV files

# %%
'''Dir nav citation:
https://softhints.com/python-change-directory-parent/
'''
curr_dir = os.path.abspath(os.curdir)
print(curr_dir)
os.chdir("..")
up1_dir = os.path.abspath(os.curdir)
print(up1_dir)
# Out:
# C:\Users\acarr\Documents\GitHub\599_team_project\deliverables
# C:\Users\acarr\Documents\GitHub\599_team_project

# %% [markdown]
# Get current date/time to append to file name string

# %%
today = dt.datetime.today()
today= str(today)
today = today.replace(':', '-').replace('.', '').replace(' ', '_')
print(today)
print(type(today))
# Out:
# 2023-07-06_13-43-29430930
# <class 'str'>

# %% [markdown]
# Establish full file name path

# %%
data_location = 'data'

scraped_file_name = f'data_scraped_amc_{today}.csv'
all_file_name = f'data_all_amc_{today}.csv'

scraped_file_path01 = os.path.join(up1_dir, data_location, scraped_file_name)
all_file_path01 = os.path.join(up1_dir, data_location, all_file_name)

print(f'CSV file path: {scraped_file_path01}')
print(f'CSV file path: {all_file_path01}')
# Out:
# CSV file path: C:\Users\acarr\Documents\GitHub\599_team_project\data\data_scraped_amc_2023-07-06_13-43-29430930.csv
# CSV file path: C:\Users\acarr\Documents\GitHub\599_team_project\data\data_all_amc_2023-07-06_13-43-29430930.csv

# %% [markdown]
# Send dataframe to CSV

# %%
slct_tbl_full_df02.to_csv(all_file_path01, index=False)

# %% [markdown]
# ### Establish logging policy

# %% [markdown]
# Configure logging so that connection errors can be reviewed. Logging output is sent to the pymysql.log file.

# %%
'''Logging citations (see additional code in following code blocks:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/;
https://docs.python.org/3/howto/logging.html#logging-basic-example;
https://docs.python.org/3/howto/logging.html#logging-to-a-file;
https://docs.python.org/3/howto
/logging-cookbook.html#using-a-rotating-log-file-handler;
https://docs.python.org/3/howto
/logging-cookbook.html#using-a-timed-rotating-file-handler
'''
# Set up logging
logging.basicConfig(level=logging.INFO,
                    filename='pymysql.log',
                    filemode='a',
                    format='''>>>>>>>>>>>>>><<<<<<<<<<<<<<\n%(asctime)s - %(levelname)s - %(message)s''')

# %% [markdown]
# ### Read URLs from MySQL table to perform web scraping

# %%
nat_tbl_name = 'nar_temp'
nwa_tbl_name = 'news_articles'

# %% [markdown]
# Run the custom function through a `for` loop to load the URLs in batches from MySQL, scrape the article content from the website, then persist the scraped data back to MySQL. The script first tries to ID whether a JSON object is available for simplied parsing; if there isn't one, the script parses the HTML using BeautifulSoup, iteratively searching for different tags based on the structure of each source website. If all parsing fails, then None is written to `article_text` and an error string is displayed; otherwise the scraped text is written to the feature.

# %%
'''Connect to MqSQL table in batches citation:
OpenAI. (2021). ChatGPT [Computer software]. https://openai.com/
'''

# Batch size (number of URLs to process at a time)
batch_size = 5000

# Get the total number of URLs in the table
count_query = f"SELECT COUNT(*) FROM {nwa_tbl_name}"
cursor.execute(count_query)
total_urls = cursor.fetchone()[0]
print(f'URL Count: {total_urls}')

# Start timer
start_time = dt.datetime.today()

# Calculate the number of batches required
num_batches = (total_urls // batch_size) + 1

# Process URLs in batches
for batch in range(num_batches):
    offset = batch * batch_size

    # Retrieve URLs from the MySQL table in the current batch
    query = f'''
    SELECT url FROM {nwa_tbl_name}
    WHERE article_text IS NULL
    AND LEFT(url, 19) <> 'https://disneyparks'
    LIMIT {batch_size}
    OFFSET {offset}
    '''
    
    cursor.execute(query)
    urls = cursor.fetchall()
    print(f'URL batch size: {len(urls)}')
    print(query)

    # Iterate over the URLs and scrape their contents
    for idx, url in enumerate(urls):
        url = url[0]  # Extract the URL from the tuple

        # Make an HTTP request to the URL
        response = requests.get(url)
        print(f'URL #{idx} Response: {response.status_code}; URL: {url} ', end='')
        time.sleep(5 + 10 * random.random())

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the HTML content using BeautifulSoup
            soup = BeautifulSoup(response.content, 'html.parser')
            
            '''_______________________________________________'''

            # Extract the raw text from the HTML
            #print(soup.prettify())

            # Check for available JSON object
            try:
                script_tag = soup.find('script', {'type': 'application/ld+json'})
                if script_tag != None:
                    article_json = json.loads(script_tag.string)
                    article_content = article_json['articleBody']
                    #print('JSON article content:', article_content)

            # If no JSON object available, use Beautiful Soup to look for available 
            # HTML tags
            except:
                json_err02 = '; Missing JSON object'
                article_body = soup.find('div', class_='article__content-container')

                if article_body is None: # Fox & breitbert(sometimes)
                    article_body = soup.find('p', class_="speakable")
                    if article_body is None: # breitbert(most)
                        article_body = soup.find('div', class_='entry-content')
                        if article_body is None: # WashPost
                            article_body = soup.find('div',class_='article-body')
                            if article_body is None: # USA Today
                                article_body = soup.find('div',class_='gnt_ar_b')
                                if article_body is None: # USA Today
                                    article_body = soup.find('div',id='primary')
                                    if article_body is None: # ABC
                                        article_body = soup.find('div',class_='FITT_Article_main__body')
                                        if article_body is None: # BuzzFeed
                                            article_body = soup.find('article')
                                            if article_body is None: # BuzzFeed
                                                article_body = soup.find('div',id='1-main-content')

                if article_body is not None:
                    article_content = article_body.get_text()
                    #print('Article body content:', article_content)
                    #print('Rejoice, parse was successful!')
                else:
                    try:
                        print(json_err02)
                    except:
                        pass
                    print(f'^^^Parse not successful^^^')
                    article_content = None
                    #print('Article not parse:', article_content)

            '''_______________________________________________'''

            # Update the MySQL table with the scraped text
            update_query = '''
            UPDATE news_articles SET article_text = %s
            WHERE url = %s
            '''
            
            #print('.', end='')
            #print(update_query)
            #print('Article content to post:', article_content, '\n')
            cursor.execute(update_query, (article_content, url))
            db_conn.commit()
            
# End timer script
end_time = dt.datetime.today()
time_elapse = end_time - start_time
print(f'Start Time = {start_time}')
print(f'End Time = {end_time}')
print(f'Elapsed Time = {time_elapse}')
# Out:
# URL Count: 35928
# URL batch size: 5000
#
#     SELECT url FROM news_articles
#     WHERE article_text IS NULL
#     AND LEFT(url, 19) <> 'https://disneyparks'
#     LIMIT 5000
#     OFFSET 0
#
# URL #0 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/97-year-cycled-100000-miles-100387792 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #1 Response: 403; URL: https://www.wsj.com/livecoverage/stock-market-today-dow-jones-06-26-2023 URL #2 Response: 403; URL: https://www.wsj.com/livecoverage/stock-market-today-dow-jones-06-27-2023 URL #3 Response: 200; URL: https://reviewed.usatoday.com/gaming/content/nzxt-relay-review-comfortable-fit-and-clear-comms-but-too-expensive ; Missing JSON object
# ^^^Parse not successful^^^
# URL #4 Response: 200; URL: https://abcnews.go.com/Travel/video/ride-virgin-galactics-1st-paying-flight-100536953 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #5 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/bagel-shop-asked-customers-silly-dance-entered-100499201 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #6 Response: 404; URL: https://golfweek.usatoday.com/2023/06/21/usga-cashes-in-on-covid-19-insurance-claim-mike-daviss-exit-package-and-more-from-the-usgas-990-filing/ URL #7 Response: 403; URL: https://www.wsj.com/articles/robert-f-kennedy-election-presidential-campaign-2024-5265d2b8 URL #8 Response: 200; URL: https://abcnews.go.com/US/video/rehabilitated-sea-turtle-returns-ocean-100553136 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #9 Response: 200; URL: https://reviewed.usatoday.com/laptops/content/hp-dragonfly-pro-2023-review-so-close ; Missing JSON object
# ^^^Parse not successful^^^
# URL #10 Response: 200; URL: https://abcnews.go.com/WNT/video/exclusive-james-cameron-weighs-incident-100321736 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #11 Response: 200; URL: https://abcnews.go.com/US/video/miniature-cow-duck-besties-dip-100288924 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #12 Response: 200; URL: https://reviewed.usatoday.com/smarthome/content/govee-led-strip-light-m1-matter-compatible-review ; Missing JSON object
# ^^^Parse not successful^^^
# URL #13 Response: 200; URL: https://www.businessinsider.com/how-lafrieda-prepares-sells-270-million-meat-beef-per-year-2023-6 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #14 Response: 403; URL: https://www.wsj.com/articles/putin-moves-to-seize-control-of-wagners-global-empire-26d49286 URL #15 Response: 200; URL: https://reviewed.usatoday.com/tech/content/google-pixel-tablet-review ; Missing JSON object
# ^^^Parse not successful^^^
# URL #16 Response: 200; URL: https://abcnews.go.com/WNT/video/labrador-retriever-knack-finding-lost-frisbees-100517566 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #17 Response: 200; URL: https://abcnews.go.com/Lifestyle/video/dad-scales-waterslide-stuck-daughter-100262738 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #18 Response: 200; URL: https://abcnews.go.com/GMA/Family/video/nurse-delivered-sons-future-wife-22-years-ago-100346245 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #19 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/smart-goat-finds-treats-dispenser-100388163 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #20 Response: 403; URL: https://www.wsj.com/articles/mondays-are-the-new-office-fight-efd3ce3f URL #21 Response: 200; URL: https://abcnews.go.com/International/video/alpacas-stroll-streets-tokyo-100314320 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #22 Response: 200; URL: https://reviewed.usatoday.com/gaming/features/oled-monitor-brightness-review ; Missing JSON object
# ^^^Parse not successful^^^
# URL #23 Response: 200; URL: https://abcnews.go.com/GMA/Culture/video/prince-william-recounts-visit-homeless-shelter-mom-princess-100387684 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #24 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/toddler-dressed-flounder-mermaid-meets-ariel-disneyland-100249934 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #25 Response: 200; URL: https://abcnews.go.com/US/video/man-finds-passenger-commercial-flight-100476960 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #26 Response: 200; URL: https://abcnews.go.com/US/video/deadly-tornado-rips-buildings-indiana-100375698 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #27 Response: 403; URL: https://www.wsj.com/articles/chinese-balloon-used-american-tech-to-spy-on-americans-2e3f5039 URL #28 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/therapy-dog-graduates-high-school-classmates-100320168 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #29 Response: 200; URL: https://abcnews.go.com/US/video/lightning-strikes-tail-aircraft-100390071 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #30 Response: 200; URL: https://abcnews.go.com/International/video/dog-residents-rescued-chile-floodwaters-100366705 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #31 Response: 200; URL: https://reviewed.usatoday.com/tech/features/hp-instant-ink-benefits-monthly-ink-and-toner-subscription ; Missing JSON object
# ^^^Parse not successful^^^
# URL #32 Response: 200; URL: https://abcnews.go.com/US/video/orcas-swim-side-side-off-california-coast-100490712 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #33 Response: 200; URL: https://reviewed.usatoday.com/gaming/content/samsung-odyssey-oled-g9-review-hugely-impressive ; Missing JSON object
# ^^^Parse not successful^^^
# URL #34 Response: 200; URL: https://reviewed.usatoday.com/gaming/content/gamevice-flex-android-ios-review ; Missing JSON object
# ^^^Parse not successful^^^
# URL #35 Response: 200; URL: https://abcnews.go.com/International/video/man-finds-avatar-bioluminescence-australian-creek-100218458 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #36 Response: 403; URL: https://www.wsj.com/articles/mormon-church-temple-spending-spree-utah-e167977f URL #37 Response: 403; URL: https://www.wsj.com/articles/are-lawmakers-seeking-healthy-limits-on-junk-food-or-acting-as-food-police-3c28c5 URL #38 Response: 200; URL: https://reviewed.usatoday.com/accessibility/features/accessible-keyboard-ergonomic-lap-for-carpal-tunnel ; Missing JSON object
# ^^^Parse not successful^^^
# URL #39 Response: 403; URL: https://www.wsj.com/articles/simon-schuster-draws-bid-from-investor-backed-by-abu-dhabi-based-sovereign-fund-2787adf URL #40 Response: 403; URL: https://www.wsj.com/articles/questions-swirl-on-russia-truce-as-putin-prigozhin-stay-silent-b8a44500 URL #41 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/icymi-puppy-outgrows-hangout-spot-100353282 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #42 Response: 200; URL: https://www.businessinsider.com/hunter-biden-criminal-charges-expected-to-plead-guilty-2023-6 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #43 Response: 403; URL: https://www.wsj.com/articles/twitter-ceo-intervened-to-mend-google-relationship-after-cloud-payment-issue-1e61186f URL #44 Response: 200; URL: https://abcnews.go.com/Lifestyle/video/drones-form-wine-bottle-100436242 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #45 Response: 403; URL: https://www.wsj.com/articles/private-eye-found-guilty-of-acting-as-illegal-chinese-agent-17e7ca71 URL #46 Response: 403; URL: https://www.wsj.com/articles/propublica-misleads-its-readers-alito-gifts-disclosure-alaska-singer-23b51eda URL #47 Response: 403; URL: https://www.wsj.com/sports/baseball/domingo-german-perfect-game-yankees-ad62f2ff URL #48 Response: 200; URL: https://abcnews.go.com/WNT/video/delta-flight-makes-emergency-landing-gear-100456180 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #49 Response: 200; URL: https://reviewed.usatoday.com/tech/features/cheap-phone-plans-7-best-inexpensive-plans-2023 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #50 Response: 200; URL: https://abcnews.go.com/US/video/man-captures-adorable-fox-pups-backyard-100366704 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #51 Response: 200; URL: https://abcnews.go.com/International/video/house-brink-collapse-after-heavy-rainfall-chile-100445950 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #52 Response: 200; URL: https://www.businessinsider.com/why-natural-latex-mattresses-are-so-expensive-2023-6 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #53 Response: 200; URL: https://abcnews.go.com/Lifestyle/video/rembrandt-museum-offers-visitors-souvenir-tattoos-100271287 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #54 Response: 403; URL: https://www.wsj.com/articles/the-world-review-history-branched-out-4d18193a URL #55 Response: 200; URL: https://abcnews.go.com/US/video/alligator-charges-fisherman-100356045 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #56 Response: 403; URL: https://www.wsj.com/articles/reddit-hackers-threaten-to-leak-stolen-data-if-company-doesnt-pay-4-5-million-abandon-fees-b0548605 URL #57 Response: 200; URL: https://abcnews.go.com/GMA/Family/video/texas-mom-starts-girl-scout-troop-lgbtq-youth-100551757 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #58 Response: 403; URL: https://www.wsj.com/articles/u-s-navy-detected-titan-sub-implosion-days-ago-6844cb12 URL #59 Response: 403; URL: https://www.wsj.com/articles/deadly-fungal-infection-candida-auris-yeast-ab73b9d0 URL #60 Response: 200; URL: https://abcnews.go.com/GMA/Family/video/4-year-shares-sweet-encounter-hummingbird-wearing-feeder-100454779 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #61 Response: 403; URL: https://www.wsj.com/articles/big-news-publishers-look-to-team-up-to-address-impact-of-ai-80c3b88e URL #62 Response: 200; URL: https://abcnews.go.com/International/video/drone-captures-pod-whales-swimming-off-australia-100375699 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #63 Response: 200; URL: https://reviewed.usatoday.com/tech/features/hp-instant-ink-plans-how-pick-best-printing-plan ; Missing JSON object
# ^^^Parse not successful^^^
# URL #64 Response: 200; URL: https://abcnews.go.com/US/video/tornado-touches-florida-100225533 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #65 Response: 404; URL: https://www.usatoday.com/story/money/cars/2023/06/21/used-car-values-drop-economy-slowdown/70341412007/ URL #66 Response: 404; URL: https://wolverineswire.usatoday.com/2023/06/26/michigan-football-now-predicted-to-land-idaho-2024-wide-receiver-gatlin-bair/ URL #67 Response: 403; URL: https://www.wsj.com/articles/frank-lloyd-wright-built-120-homes-near-the-end-of-his-life-just-one-original-owner-remains-83ed1d74 URL #68 Response: 200; URL: https://abcnews.go.com/International/video/zoo-animals-beat-heat-pride-themed-popsicles-100453426 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #69 Response: 404; URL: https://celticswire.usatoday.com/2023/06/19/nba-boston-celtics-smart-offs-23/ URL #70 Response: 404; URL: https://rolltidewire.usatoday.com/2023/06/25/alabama-football-wishful-thinking-not-honest-assessment-has-lead-to-nick-saban-alabama-being-counted-out/ URL #71 Response: 200; URL: https://abcnews.go.com/International/video/suspected-gas-leak-explosion-injures-dozens-central-paris-100292314 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #72 Response: 403; URL: https://www.wsj.com/articles/ozempic-maker-sues-spas-and-clinics-selling-custom-made-versions-7e885f7a URL #73 Response: 403; URL: https://www.wsj.com/livecoverage/stock-market-today-dow-jones-06-23-2023 URL #74 Response: 403; URL: https://www.wsj.com/livecoverage/russia-wagner-prigozhin-putin URL #75 Response: 200; URL: https://abcnews.go.com/GMA/Culture/video/rory-mcilroy-scores-career-hole-100330105 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #76 Response: 200; URL: https://www.businessinsider.com/supreme-court-strikes-down-bidens-student-debt-relief-plan-2023-6 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #77 Response: 403; URL: https://www.wsj.com/articles/no-more-shots-pill-versions-of-ozempic-like-drugs-are-coming-ca286ca2 URL #78 Response: 200; URL: https://abcnews.go.com/GMA/Living/video/dog-loves-clean-litter-100543618 ; Missing JSON object
# ^^^Parse not successful^^^
# URL #79 Response: 200; URL: https://reviewed.usatoday.com/laptops/content/razer-blade-14-2023-review ; Missing JSON object
# ^^^Parse not successful^^^
# URL #80 Response: 200; URL: https://www.cnbc.com/2023/06/23/gay-male-couples-face-more-challenges-higher-costs-to-start-a-family.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #81 Response: 200; URL: https://www.cnbc.com/2023/06/22/boeing-supplier-spirit-aerosystems-stops-production-at-wichita-plant.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #82 Response: 200; URL: https://www.cnbc.com/2023/06/25/best-us-cities-for-renters.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #83 Response: 404; URL: https://nypost.com/2023/06/29/c/ URL #84 Response: 200; URL: https://www.cnbc.com/2023/06/23/il-makiage-creator-oddity-has-filed-to-go-public.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #85 Response: 200; URL: https://www.cnbc.com/2023/06/30/biden-says-hes-working-on-a-new-path-to-student-loan-forgiveness-after-supreme-court-decision.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #86 Response: 200; URL: https://www.cnbc.com/2023/06/20/rescuers-race-against-time-to-find-the-missing-sub-in-the-atlantic-bound-for-the-titanic-site.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #87 Response: 200; URL: https://www.cnbc.com/2023/06/22/bank-of-england-june-decision-50-basis-point-rate-hike-to-tackle-persistent-inflation.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #88 Response: 200; URL: https://www.cnbc.com/2023/06/21/gsk-rsv-vaccine-for-older-adults-provides-long-term-protection.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #89 Response: 200; URL: https://www.cnbc.com/2023/06/20/china-cuts-two-more-key-lending-rates-as-economy-sputters.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #90 Response: 200; URL: https://www.cnbc.com/2023/06/30/apples-market-cap-passes-3-trillion-in-early-trading.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #91 Response: 200; URL: https://www.cnbc.com/2023/06/29/ex-pfizer-employee-charged-over-trading-on-paxlovid-data.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #92 Response: 200; URL: https://www.cnbc.com/2023/06/20/alibaba-ceo-daniel-zhang-explains-why-he-is-stepping-down-in-staff-memo.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #93 Response: 200; URL: https://www.cnbc.com/2023/06/22/us-and-india-set-to-announce-flurry-of-deals-on-defense-chips-ai.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #94 Response: 200; URL: https://www.cnbc.com/2023/06/28/canadian-wildfire-smoke-is-impacting-air-quality-in-new-york-again.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #95 Response: 200; URL: https://www.cnbc.com/2023/06/28/overstockcom-to-rename-website-bed-bath-beyond.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #96 Response: 200; URL: https://www.cnbc.com/2023/06/21/high-german-energy-prices-are-seeing-some-companies-relocate-bdi.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #97 Response: 200; URL: https://www.cnbc.com/2023/06/28/berberine-is-being-called-natures-ozempic-heres-what-to-know.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #98 Response: 200; URL: https://www.cnbc.com/2023/06/28/peter-thiel-nonprofit-apparently-donated-to-left-leaning-group.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #99 Response: 200; URL: https://www.cnbc.com/2023/06/22/what-to-know-about-investing-in-the-first-spot-bitcoin-etf.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #100 Response: 200; URL: https://www.cnbc.com/2023/06/30/white-house-releases-report-on-solar-geoengineering.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #101 Response: 200; URL: https://www.vox.com/scotus/23742240/affirmative-action-unc-harvard-education-culture-wars ; Missing JSON object
# ^^^Parse not successful^^^
# URL #102 Response: 200; URL: https://www.cnbc.com/2023/06/30/energy-transition-is-lagging-oil-demand-will-stay-industry-players.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #103 Response: 200; URL: https://www.forbes.com/video/6329855321112/if-youre-an-investor-right-now-you-should-invest-in-women-says-ceo-of-vc-network/ URL #104 Response: 200; URL: https://www.cnbc.com/2023/06/23/cfp-chatgpt-wont-help-you-beat-the-stock-market-but-has-other-uses.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #105 Response: 200; URL: https://www.cnbc.com/2023/06/20/stock-markets-the-chinese-dragons-still-dozing.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #106 Response: 200; URL: https://www.cnbc.com/2023/06/22/flavored-e-cigarette-sales-usage-up-among-youths-.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #107 Response: 404; URL: https://www.forbes.com/video/6330200461112/carlos-ghosn-discusses-arrest-evs-and-1b-lawsuit-against-nissan/ URL #108 Response: 200; URL: https://www.cnbc.com/2023/06/27/wagner-revolt-russias-neighbors-want-to-beef-up-natos-eastern-flank.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #109 Response: 200; URL: https://www.cnbc.com/2023/06/23/siemens-energy-scraps-profit-outlook-as-wind-turbine-troubles-deepen.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #110 Response: 200; URL: https://www.cnbc.com/2023/06/30/stock-markets-the-us-economy-refuses-to-buckle.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #111 Response: 200; URL: https://www.cnbc.com/2023/06/27/openai-powered-app-from-microsoft-is-coming-to-epic-systems.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #112 Response: 200; URL: https://www.cnbc.com/2023/06/22/norway-central-bank-raises-rate-to-15-year-high-with-more-to-come.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #113 Response: 200; URL: https://www.cnbc.com/2023/06/21/inside-chinas-spy-war-on-american-corporations.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #114 Response: 200; URL: https://www.cnbc.com/2023/06/28/debris-from-implosion-of-titanic-bound-submersible-is-returned-to-land.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #115 Response: 200; URL: https://www.cnbc.com/2023/06/29/us-dutch-set-to-hit-chinas-chipmakers-with-one-two-punch.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #116 Response: 200; URL: https://www.cnbc.com/2023/06/21/op-ed-demystifying-private-credit-amid-a-frozen-ipo-market.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #117 Response: 200; URL: https://www.cnbc.com/2023/06/27/stocks-making-the-biggest-moves-midday-ride-wba-dal-and-more.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #118 Response: 200; URL: https://www.cnbc.com/2023/06/23/stocks-making-the-biggest-moves-midday-sbux-kmx-spce.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #119 Response: 200; URL: https://www.cnbc.com/2023/06/22/turkeys-central-bank-hikes-interest-rate-to-15percent-in-dramatic-u-turn-to-tackle-40percent-inflation.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #120 Response: 200; URL: https://www.vox.com/2024-elections/23720391/vivek-ramaswamy-affirmative-action-woke-capitalism-ideas ; Missing JSON object
# ^^^Parse not successful^^^
# URL #121 Response: 200; URL: https://www.cnbc.com/2023/06/20/cramers-lightning-round-icahn-is-too-dangerous.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #122 Response: 200; URL: https://www.cnbc.com/2023/06/20/missing-titanic-submersible-41-hours-or-less-of-oxygen-left.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #123 Response: 200; URL: https://www.cnbc.com/2023/06/30/goldman-in-talks-to-offload-apple-financial-products-to-american-express-source.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #124 Response: 200; URL: https://www.cnbc.com/2023/06/21/hunter-biden-guilty-plea-july-hearing.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #125 Response: 200; URL: https://www.cnbc.com/2023/06/23/401k-vesting-what-to-know.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #126 Response: 200; URL: https://www.cnbc.com/2023/06/30/shein-denies-us-ipo-rumors.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #127 Response: 200; URL: https://www.cnbc.com/2023/06/27/heres-what-to-know-about-alternative-investments-before-buying.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #128 Response: 200; URL: https://www.cnbc.com/2023/06/27/delta-air-lines-2023-guidance-investor-day.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #129 Response: 200; URL: https://www.cnbc.com/2023/06/25/stock-market-today-live-updates.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #130 Response: 200; URL: https://www.cnbc.com/2023/06/23/us-china-tech-war-why-generative-ai-could-be-the-next-battleground.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #131 Response: 200; URL: https://www.cnbc.com/2023/06/26/china-says-it-supports-russia-says-wagner-rebellion-is-internal-affair.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #132 Response: 200; URL: https://www.cnbc.com/2023/06/28/states-pay-huge-sums-to-lure-chip-makers-on-top-of-federal-billions.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #133 Response: 200; URL: https://www.cnbc.com/2023/06/20/alibaba-announces-eddie-wu-to-succeed-daniel-zhang-as-ceo.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #134 Response: 200; URL: https://www.cnbc.com/2023/06/29/virgin-galactic-first-commercial-spaceflight-live-stream-updates.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #135 Response: 200; URL: https://www.cnbc.com/2023/06/28/carl-pei-smartphone-startup-nothing-raises-96-million-from-investors.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #136 Response: 200; URL: https://www.cnbc.com/2023/06/27/saudi-aramco-looks-to-china-and-india-to-prop-up-oil-markets.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #137 Response: 200; URL: https://www.cnbc.com/2023/06/29/here-are-affordable-ways-to-save-on-cooling-costs-this-summer.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #138 Response: 200; URL: https://www.cnbc.com/2023/06/26/employees-say-their-well-being-has-worsened-but-bosses-disagree-survey.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #139 Response: 200; URL: https://www.cnbc.com/2023/06/26/oil-prices-climb-after-russia-mutiny-stoke-fears-of-supply-disruption.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #140 Response: 200; URL: https://www.cnbc.com/2023/06/20/bitcoin-hits-new-high-for-june-as-more-financial-incumbents-signal-commitment-to-crypto.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #141 Response: 200; URL: https://www.cnbc.com/2023/06/23/musk-zuckerberg-ufc-cage-match-will-cost-100-dollars.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #142 Response: 200; URL: https://www.cnbc.com/2023/06/28/delta-passengers-exit-their-flight-using-the-jet-slide-after-the-plane-lands-without-gear-extended.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #143 Response: 200; URL: https://www.cnbc.com/2023/06/26/apple-reportedly-plans-new-apple-watch-ultra-with-iphone-15-this-fall.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #144 Response: 200; URL: https://www.cnbc.com/2023/06/26/outdated-rainfall-models-put-billions-in-new-infrastructure-at-risk.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #145 Response: 200; URL: https://www.cnbc.com/2023/06/21/grab-cuts-1000-jobs-its-biggest-round-of-layoffs-since-the-pandemic.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #146 Response: 200; URL: https://www.cnbc.com/2023/06/28/nvidia-downplays-possible-us-chip-export-restrictions.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #147 Response: 200; URL: https://www.vox.com/scotus/23742240/affirmative-action-supreme-court-college-admissions-unc-harvard-education-culture-wars ; Missing JSON object
# ^^^Parse not successful^^^
# URL #148 Response: 200; URL: https://www.cnbc.com/2023/06/24/bricks-over-bytes-new-hard-asset-etf-places-big-bet-on-real-estate.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #149 Response: 200; URL: https://www.cnbc.com/2023/06/23/lithuania-building-a-110-million-tech-campus-the-largest-in-europe.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #150 Response: 200; URL: https://www.cnbc.com/2023/06/26/stocks-making-the-biggest-moves-midday-pfizer-lucid-wsfs-financial-and-more.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #151 Response: 200; URL: https://www.cnbc.com/2023/06/21/voicemod-ai-humans-let-gamers-modify-their-voices-in-real-time.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #152 Response: 200; URL: https://www.cnbc.com/2023/06/25/us-coast-guard-will-lead-investigation-of-titan-implosion-with-help-from-canada-france-uk.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #153 Response: 200; URL: https://www.cnbc.com/2023/06/26/japan-backed-fund-to-buy-semiconductor-firm-jsr-for-6point3-billion.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #154 Response: 200; URL: https://www.cnbc.com/2023/06/25/rebellion-in-russia-reveals-cracks-in-putins-regime-secretary-blinken-says.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #155 Response: 200; URL: https://www.cnbc.com/2023/06/24/odds-of-winning-427-million-dollar-powerball-jackpot.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #156 Response: 200; URL: https://www.cnbc.com/2023/06/28/nvidia-dips-on-report-us-mulling-new-ai-chip-restrictions-for-china.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #157 Response: 200; URL: https://www.cnbc.com/2023/06/27/why-a-spending-plan-is-better-than-a-budget-financial-psychologist.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #158 Response: 200; URL: https://www.cnbc.com/2023/06/21/blinken-talked-up-us-china-economic-ties-in-high-stakes-beijing-trip.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #159 Response: 200; URL: https://www.cnbc.com/2023/06/21/robert-f-kennedy-jr-gets-boost-wall-street-veteran.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #160 Response: 200; URL: https://www.cnbc.com/2023/06/28/asphalt-maker-crh-faces-golden-age-with-green-strings-attached.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #161 Response: 200; URL: https://www.cnbc.com/2023/06/23/southwest-airlines-reaches-tentative-agreement-with-mechanics-union.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #162 Response: 200; URL: https://www.cnbc.com/2023/06/29/jim-cramers-guide-to-investing-never-buy-all-at-once.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #163 Response: 200; URL: https://www.cnbc.com/2023/06/23/apples-tim-cook-and-tech-execs-meet-indian-prime-minister-modi-.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #164 Response: 200; URL: https://www.cnbc.com/2023/06/28/yevgeny-prigozhin-what-could-be-next-for-russias-mutinous-mercenary-chief.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #165 Response: 200; URL: https://www.cnbc.com/2023/06/21/canadian-aircraft-detects-underwater-noises-in-search-for-sub-near-titanic.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #166 Response: 200; URL: https://www.cnbc.com/2023/06/26/trump-documents-case-media-want-witness-list-revealed.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #167 Response: 200; URL: https://www.cnbc.com/2023/06/30/euro-zone-inflation-june-2023.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #168 Response: 200; URL: https://www.vox.com/culture/23775516/antoni-bumba-blizzy-mcguire-uniekue-selyna-brillare-junlper-kay-poyer-trans-it-girls ; Missing JSON object
# ^^^Parse not successful^^^
# URL #169 Response: 200; URL: https://www.cnbc.com/2023/06/26/aston-martin-turns-to-us-ev-company-lucid-for-high-tech-help.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #170 Response: 200; URL: https://www.cnbc.com/2023/06/27/google-distances-itself-from-drag-performance-after-employee-petition.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #171 Response: 200; URL: https://www.cnbc.com/2023/06/20/drug-prices-drugmakers-aim-to-fight-medicare-negotiations-at-scotus.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #172 Response: 200; URL: https://www.cnbc.com/2023/06/30/what-supreme-court-student-loan-forgiveness-ruling-means-for-the-economy.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #173 Response: 200; URL: https://www.cnbc.com/2023/06/22/qatari-investment-fund-seeks-stake-in-nba-wizards-parent-monumental.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #174 Response: 200; URL: https://www.cnbc.com/2023/06/21/stocks-making-the-biggest-moves-premarket.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #175 Response: 200; URL: https://www.cnbc.com/2023/06/28/ai-is-not-all-hype-its-the-fourth-industrial-revolution-dan-ives.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #176 Response: 200; URL: https://www.cnbc.com/2023/06/21/5-things-to-know-before-the-stock-market-opens-wednesday-june-21.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #177 Response: 200; URL: https://www.cnbc.com/2023/06/29/ai-generated-drug-begins-clinical-trials-in-human-patients.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #178 Response: 200; URL: https://www.cnbc.com/2023/06/27/japan-stocks-are-roaring-back-this-rally-may-be-different-from-1990.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #179 Response: 200; URL: https://www.cnbc.com/2023/06/29/asia-pushes-back-on-excessive-currency-moves-amid-enduring-dollar-strength.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #180 Response: 200; URL: https://www.cnbc.com/2023/06/24/sublime-systems-co-founders-making-the-electric-vehicle-of-cement.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #181 Response: 410; URL: https://www.forbes.com/sites/digital-assets/2023/06/25/tradfi-will-accelerate-the-next-leg-of-crypto-adoption/ URL #182 Response: 200; URL: https://www.cnbc.com/2023/06/22/pfizer-gsk-rsv-shots-may-prevent-thousands-of-hospitalizations.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #183 Response: 200; URL: https://www.cnbc.com/2023/06/27/audi-ex-boss-becomes-first-top-manager-sentenced-for-fraud-in-2015-diesel-scandal.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #184 Response: 200; URL: https://www.cnbc.com/2023/06/23/market-orders-vs-stop-loss-orders-which-does-the-club-use-for-trades.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #185 Response: 200; URL: https://www.cnbc.com/2023/06/22/shein-temu-evade-us-tariff-and-human-rights-law-on-imports-house-report.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #186 Response: 200; URL: https://www.cnbc.com/2023/06/27/wise-shares-surge-as-higher-interest-rates-help-fintech-triple-profits.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #187 Response: 200; URL: https://www.cnbc.com/2023/06/22/vice-media-fortress-bankruptcy-auction.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #188 Response: 200; URL: https://www.cnbc.com/2023/06/28/finance-is-the-no-1-industry-gen-z-wants-to-work-in-says-new-research.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #189 Response: 200; URL: https://www.cnbc.com/2023/06/29/in-return-to-office-messaging-theres-now-more-stick-less-carrot.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #190 Response: 200; URL: https://www.cnbc.com/2023/06/28/do-you-believe-a-serious-recession-is-imminent-the-ipo-for-you-may-have-arrived.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #191 Response: 200; URL: https://www.cnbc.com/2023/06/20/ukraine-counteroffensive-proving-tough-as-russia-mounts-resistance.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #192 Response: 200; URL: https://www.cnbc.com/2023/06/29/southwest-pilots-union-lays-groundwork-for-potential-strike.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #193 Response: 200; URL: https://www.cnbc.com/2023/06/30/the-10-highest-grossing-movies-of-2023-so-far.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #194 Response: 200; URL: https://www.cnbc.com/2023/06/24/inside-sweetgreens-first-automated-location-plans-to-take-tech-nationwide.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #195 Response: 200; URL: https://www.cnbc.com/2023/06/28/how-a-supreme-court-case-could-affect-federal-wealth-tax-proposals.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #196 Response: 200; URL: https://www.cnbc.com/2023/06/20/eli-lilly-to-acquire-dice-therapeutics-for-2point4-billion.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #197 Response: 200; URL: https://www.cnbc.com/2023/06/21/pfizer-adult-rsv-vaccine-efficacy-18-months.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #198 Response: 200; URL: https://www.cnbc.com/2023/06/28/doj-charges-78-people-with-2point5-billion-in-health-care-fraud.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #199 Response: 200; URL: https://www.cnbc.com/2023/06/22/former-texas-rep-will-hurd-jumps-into-the-2024-gop-presidential-race.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #200 Response: 200; URL: https://www.cnbc.com/2023/06/29/3-reasons-it-can-be-smarter-to-rent-even-if-you-can-afford-to-buy.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #201 Response: 200; URL: https://www.cnbc.com/2023/06/21/cramers-lightning-round-not-a-fan-of-snap-.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #202 Response: 200; URL: https://www.cnbc.com/2023/06/20/its-official-student-loan-payments-will-restart-in-october.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #203 Response: 200; URL: https://www.cnbc.com/2023/06/21/singapore-climate-change-green-bonds-blended-financing-needed.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #204 Response: 200; URL: https://www.cnbc.com/2023/06/22/musk-picks-vegas-for-zuckerberg-cage-match-challenge.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #205 Response: 200; URL: https://www.cnbc.com/2023/06/27/jim-cramers-guide-to-investing-quality-is-key.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #206 Response: 200; URL: https://www.cnbc.com/2023/06/22/stocks-making-the-biggest-premarket-moves-.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #207 Response: 200; URL: https://www.cnbc.com/2023/06/30/student-loan-forgiveness-decision-by-supreme-court-to-hit-retailers.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #208 Response: 200; URL: https://www.cnbc.com/2023/06/30/china-beige-book-second-quarter-recovery.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #209 Response: 200; URL: https://www.cnbc.com/2023/06/21/avoid-these-confusing-phrases-at-work-language-experts-say.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #210 Response: 200; URL: https://www.cnbc.com/2023/06/28/stocks-making-the-biggest-moves-before-the-bell-gis-nvda-amd-and-more.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #211 Response: 200; URL: https://www.cnbc.com/2023/06/22/us-manufacturing-is-coming-home-and-these-industrials-could-gain.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #212 Response: 200; URL: https://www.cnbc.com/2023/06/30/indiana-jones-box-office-preview.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #213 Response: 200; URL: https://www.cnbc.com/2023/06/26/uks-national-health-service-linked-to-earlier-deaths-study.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #214 Response: 200; URL: https://www.cnbc.com/2023/06/24/high-interest-rates-economic-uncertainty-boost-corporate-defaults.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #215 Response: 200; URL: https://www.cnbc.com/2023/06/29/buy-buy-baby-dream-on-me-baby-retailer-wins-auction-for-ip.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #216 Response: 200; URL: https://www.cnbc.com/2023/06/29/imo-shipping-summit-could-clinch-biggest-climate-deal-of-the-decade.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #217 Response: 200; URL: https://www.cnbc.com/2023/06/28/watch-fed-chair-jerome-powell-speak-live-at-a-policy-forum-in-portugal.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #218 Response: 200; URL: https://www.cnbc.com/2023/06/22/norfolk-southern-derailment-safety-warning.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #219 Response: 200; URL: https://www.cnbc.com/2023/06/21/jim-cramer-says-trim-your-portfolio-and-take-something-off-the-table.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #220 Response: 200; URL: https://www.cnbc.com/2023/06/21/youre-not-god-doctors-and-patient-families-say-hca-hospitals-push-hospice-care.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #221 Response: 200; URL: https://www.cnbc.com/2023/06/30/bitcoin-slips-after-sec-reportedly-calls-etf-filings-inadequate-but-is-heading-for-a-winning-month.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #222 Response: 200; URL: https://www.cnbc.com/2023/06/22/elon-musk-and-mark-zuckerberg-had-beef-before-cage-match-challenge.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #223 Response: 200; URL: https://www.cnbc.com/2023/06/22/amazon-prime-day-2023-how-to-snag-the-best-deals.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #224 Response: 200; URL: https://www.cnbc.com/2023/06/20/bank-of-england-conundrum-deepens-as-inflation-labor-market-stay-hot.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #225 Response: 200; URL: https://www.cnbc.com/2023/06/22/cramers-lightning-round-get-rid-of-adt.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #226 Response: 200; URL: https://www.cnbc.com/2023/06/26/pfizer-to-end-development-of-experimental-obesity-pill-lotiglipron.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #227 Response: 200; URL: https://www.cnbc.com/2023/06/29/investing-in-space-india-is-a-sleeping-giant-expert-says.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #228 Response: 200; URL: https://www.cnbc.com/2023/06/30/boeing-supplier-spirit-aerosystems-reaches-agreement-with-workers-ending-strike.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #229 Response: 200; URL: https://www.cnbc.com/2023/06/22/world-bank-unveils-debt-payment-pause-for-disaster-hit-countries.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #230 Response: 200; URL: https://www.cnbc.com/2023/06/28/bis-is-government-agency-behind-chinese-ai-chip-ban-weighing-on-nvidia.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #231 Response: 200; URL: https://www.cnbc.com/2023/06/22/virgin-galactic-spce-raises-300-million-seeks-another-400-million.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #232 Response: 200; URL: https://www.cnbc.com/2023/06/29/more-bullish-on-dow-but-not-on-soft-landing-for-economy-cfo-survey.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #233 Response: 200; URL: https://www.cnbc.com/2023/06/30/espn-lays-off-on-air-talent-including-jeff-van-gundy-and-jalen-rose.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #234 Response: 200; URL: https://www.cnbc.com/2023/06/28/powell-say-more-restriction-is-coming-including-possibility-of-hikes-at-consecutive-meetings.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #235 Response: 200; URL: https://www.cnbc.com/2023/06/27/trump-attack-special-counsel-family-after-tape-revealed.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #236 Response: 200; URL: https://www.cnbc.com/2023/06/23/heres-how-workers-use-side-gigs-to-make-ends-meet-while-unemployed.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #237 Response: 200; URL: https://www.cnbc.com/2023/06/22/ocado-shares-jump-more-than-40percent-on-speculation-of-amazon-takeover.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #238 Response: 200; URL: https://www.cnbc.com/2023/06/20/elon-musk-scheduled-to-meet-indian-prime-minister-modi-on-tuesday.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #239 Response: 200; URL: https://www.cnbc.com/2023/06/23/5-things-to-know-before-the-stock-market-opens-friday-june-23.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #240 Response: 200; URL: https://www.cnbc.com/2023/06/27/pga-tour-liv-golf-merger-structure.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #241 Response: 200; URL: https://www.cnbc.com/2023/06/27/5-things-to-know-before-the-stock-market-opens-tuesday-june-27.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #242 Response: 200; URL: https://www.cnbc.com/2023/06/28/choice-of-when-to-retire-not-tied-to-amount-of-retirement-savings-report.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #243 Response: 200; URL: https://www.cnbc.com/2023/06/20/tesla-secret-configuration-disables-nag-for-autopilot-fsd.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #244 Response: 200; URL: https://www.cnbc.com/2023/06/20/us-china-relations-takeaways-from-blinkens-beijing-visit.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #245 Response: 200; URL: https://www.cnbc.com/2023/06/20/george-santos-bail-backers-will-be-revealed-thursday-judge-orders.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #246 Response: 200; URL: https://www.cnbc.com/2023/06/23/-trump-offers-millions-as-security-for-carroll-sexual-abuse-verdict-appeal.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #247 Response: 200; URL: https://www.cnbc.com/2023/06/24/us-intelligence-agencies-remain-divided-over-likely-covid-origin.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #248 Response: 200; URL: https://www.forbes.com/video/6329989097112/flight-delays-are-coming-transportation-head-warns-of-5g-interference-on-planes/ URL #249 Response: 200; URL: https://www.cnbc.com/2023/06/22/darden-restaurants-dri-q4-2023-earnings.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #250 Response: 200; URL: https://www.cnbc.com/2023/06/30/ftc-seeks-to-ban-fake-reviews-with-new-proposed-rule.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #251 Response: 200; URL: https://www.cnbc.com/2023/06/29/swedens-krona-hits-new-record-low-as-central-bank-hikes.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #252 Response: 200; URL: https://www.cnbc.com/2023/06/23/meta-to-pull-news-from-facebook-and-instagram-in-canada.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #253 Response: 200; URL: https://www.cnbc.com/2023/06/21/ice-cream-cattle-feed-winners-and-losers-as-summer-heat-bears-down.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #254 Response: 200; URL: https://www.cnbc.com/2023/06/30/wildfires-new-york-toronto-near-worst-air-quality-in-the-world.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #255 Response: 200; URL: https://www.cnbc.com/2023/06/23/how-much-money-it-takes-to-be-comfortable-with-emergency-savings.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #256 Response: 200; URL: https://www.cnbc.com/2023/06/29/self-made-millionaire-ramit-sethi-drives-same-car-he-bought-in-2005.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #257 Response: 200; URL: https://www.cnbc.com/2023/06/23/heres-how-you-can-make-for-zero-percent-capital-gains-taxes-for-2023.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #258 Response: 200; URL: https://www.cnbc.com/2023/06/25/only-a-matter-of-time-before-ai-chatbots-are-teaching-kids-in-school.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #259 Response: 200; URL: https://www.cnbc.com/2023/06/24/this-15-question-test-will-tell-you-if-youre-addicted-to-your-phone.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #260 Response: 200; URL: https://www.cnbc.com/2023/06/22/fiverr-rapper-mike-burtons-career-advice-for-new-grads.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #261 Response: 200; URL: https://www.cnbc.com/2023/06/30/supreme-court-student-loans-republicans-biden-plan-ruling.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #262 Response: 200; URL: https://www.cnbc.com/2023/06/21/watch-fed-chair-powell-speak-live-on-rate-hikes-and-more-to-a-house-panel.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #263 Response: 200; URL: https://www.cnbc.com/2023/06/28/spielberg-scorsese-pta-to-curate-films-for-tcm.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #264 Response: 200; URL: https://www.forbes.com/video/6330243381112/why-apples-partnership-with-goldman-sachs-is-the-future-of-banking/ URL #265 Response: 200; URL: https://www.cnbc.com/2023/06/23/i-have-lived-in-paris-for-12-years-heres-how-french-people-charm-everyone-they-meet.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #266 Response: 200; URL: https://www.cnbc.com/2023/06/29/pokemon-go-maker-niantic-lays-off-230-employees-cancels-games-.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #267 Response: 200; URL: https://www.cnbc.com/2023/06/25/trumps-gop-lead-grows-after-latest-indictment-poll-finds.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #268 Response: 200; URL: https://www.cnbc.com/2023/06/23/goldman-sachs-faces-writedown-on-david-solomons-greensky-deal.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #269 Response: 200; URL: https://www.cnbc.com/2023/06/22/swiss-national-bank-opts-for-smaller-rate-hike-but-says-more-are-likely.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #270 Response: 200; URL: https://www.cnbc.com/2023/06/30/google-to-block-canadian-news-outlets-from-search-results-in-canada.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #271 Response: 200; URL: https://www.forbes.com/video/6330248119112/wagner-group-leader-planned-capture-of-2-top-russian-military-leaders--report-says/ URL #272 Response: 200; URL: https://www.cnbc.com/2023/06/21/house-democrats-release-bank-reform-bills.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #273 Response: 200; URL: https://www.cnbc.com/2023/06/20/jim-cramer-says-hes-betting-on-ford-but-still-thinks-tesla-is-a-buy.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #274 Response: 200; URL: https://www.cnbc.com/2023/06/26/microsoft-ceo-nadella-said-revenue-would-reach-500-billion-by-2030.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #275 Response: 200; URL: https://www.cnbc.com/2023/06/22/moderna-files-for-fda-approval-of-updated-covid-vaccine-for-fall.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #276 Response: 200; URL: https://www.cnbc.com/2023/06/30/supreme-court-biden-student-loan-forgiveness-plan.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #277 Response: 200; URL: https://www.cnbc.com/2023/06/21/3-creative-ways-americans-are-buying-property-amid-higher-costs.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #278 Response: 200; URL: https://www.cnbc.com/2023/06/26/google-execs-hope-new-search-feature-will-help-amid-reddit-blackouts.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #279 Response: 200; URL: https://www.cnbc.com/2023/06/26/harvard-trained-neuroscientist-the-most-underrated-skill-successful-people-use-at-work.html ; Missing JSON object
# ^^^Parse not successful^^^
# URL #280 Response: 200; URL: https://www.cnbc.com/2023/06/28/trump-only-republican-lose-to-biden-paul-ryan.html ; Missing JSON object
# ^^^Parse not successful^^^
# ...
# ^^^Parse not successful^^^
# URL #604 Response: 200; URL: https://abcnews.go.com/Politics/wireStory/rural-utah-abortion-clinic-closes-amid-staff-shortages-100139430 URL #605 Response: 200; URL: https://abcnews.go.com/US/wireStory/alabama-move-quickly-draw-new-congressional-districts-100145785 URL #606 Response: 200; URL: https://www.breitbart.com/clips/2023/06/10/andy-mccarthy-there-is-a-double-standard-between-trump-hillary-but-hillary-should-have-been-prosecuted/ URL #607 Response: 200; URL: https://www.businessinsider.com/jeffrey-epstein-victims-5-million-deutsche-bank-settlement-2023-6 URL #608 Response: 200; URL: https://abcnews.go.com/Business/wireStory/buttigieg-us-green-corridors-initiative-key-cutting-shipping-100191933 URL #609 Response: 200; URL: https://www.usatoday.com/story/news/politics/2023/06/17/trump-indictments-independents-schiff-censure/70329318007/ URL #610 Response: 200; URL: https://www.nbcnews.com/news/education/naacp-says-disappointed-biden-ended-pause-federal-student-loan-payment-rcna89104 URL #611 Response: 200; URL: https://ftw.usatoday.com/article/how-to-watch-eric-cole-at-the-u-s-open-live-stream-tv-channel-odds URL #612 Response: 200; URL: https://auburnwire.usatoday.com/lists/auburn-footballs-2024-commits-recruiting-class-tracker-hugh-freeze/ URL #613 Response: 200; URL: https://www.cnn.com/2023/06/12/us/philadelphia-i95-collapse-fire-monday/index.html URL #614 Response: 200; URL: https://abcnews.go.com/Business/wireStory/german-government-coalition-agrees-bring-disputed-heating-bill-100044349 URL #615 Response: 200; URL: https://www.businessinsider.com/how-to-fix-whatsapp-imessage-mistakes-2023-6 URL #616 Response: 200; URL: https://trojanswire.usatoday.com/lists/pac-12-media-rights-deal-takes-center-stage-after-san-diego-state-movement/ URL #617 Response: 200; URL: https://www.buzzfeed.com/morgansloss1/fbi-cia-agents-secrets-and-stories-1-1 URL #618 Response: 200; URL: https://www.msnbc.com/rachel-maddow-show/maddowblog/jared-bernsteins-senate-confirmation-vote-matters-rcna89785 URL #619 Response: 200; URL: https://www.foxnews.com/sports/heats-erik-spoelstra-lauds-mascots-toughness-bizarre-conor-mcgregor-incident URL #620 Response: 200; URL: https://www.cnn.com/2023/06/16/entertainment/jennifer-aniston-courteney-cox-friends-nicknames/index.html URL #621 Response: 200; URL: https://www.nbcnews.com/news/world/uganda-school-attack-congo-islamic-state-allied-democratic-forces-rcna89858 URL #622 Response: 200; URL: https://abcnews.go.com/International/wireStory/scottish-charity-marys-meals-wins-spains-princess-asturias-100063504 URL #623 Response: 200; URL: https://www.businessinsider.com/covert-ukrainian-force-says-focus-killing-russian-officers-cnn-2023-6 URL #624 Response: 200; URL: https://saintswire.usatoday.com/2023/06/14/saints-minicamp-practice-report-taysom-hill-quarterback-stats/ URL #625 Response: 200; URL: https://www.cnn.com/2023/06/13/sport/stanley-cup-final-golden-knights-panthers-spt-intl?cid=external-feeds_iluminar_yahoo URL #626 Response: 200; URL: https://volswire.usatoday.com/2023/06/17/tennessee-vols-football-recruitng-finalist-boo-carter-set-to-make-commitment-announcement/ URL #627 Response: 200; URL: https://okcthunderwire.usatoday.com/2023/06/19/report-vasilije-micic-in-okc-for-potential-contract-talks/ URL #628 Response: 200; URL: https://www.breitbart.com/entertainment/2023/06/14/paul-mccartney-says-the-beatles-last-song-was-created-with-help-from-artificial-intelligence/ URL #629 Response: 200; URL: https://bullswire.usatoday.com/2023/06/10/chicago-bulls-least-wanted-gm-job-nba/ URL #630 Response: 200; URL: https://coltswire.usatoday.com/2023/06/14/indianapolis-colts-daniel-scott-injury-torn-acl-update-news/ URL #631 Response: 200; URL: https://www.cnn.com/2023/06/15/politics/republican-reaction-alleged-audio-recordings-biden-bribery-scheme/index.html URL #632 Response: 200; URL: https://www.foxnews.com/entertainment/ben-affleck-matt-damons-production-company-slams-donald-trumps-campaign-ad-air-aud ...
# ^^^Parse not successful^^^
# URL #928 Response: 200; URL: https://www.businessinsider.com/guides/streaming/how-to-watch-us-open-golf-live-stream-free-anywhere-2023-final-round URL #929 Response: 200; URL: https://www.breitbart.com/2024-election/2023/06/11/biden-centers-trangenderism-flag-white-house/ URL #930 Response: 200; URL: https://www.cnn.com/2023/06/10/tennis/french-open-final-preview-djokovic-ruud-spt-intl/index.html URL #931 Response: 200; URL: https://abcnews.go.com/Politics/whitehouse-unclear-trump-appointed-judge-overseeing-federal-case/story?id=100165584 URL #932 Response: 200; URL: https://www.usatoday.com/story/sports/cycling/2023/06/16/gino-mader-dies-after-crash-tour-de-suisse/70329051007/ URL #933 Response: 200; URL: https://abcnews.go.com/International/wireStory/us-japan-philippines-agree-strengthen-security-ties-amid-100137744 URL #934 Response: 200; URL: https://abcnews.go.com/US/9-charged-thefts-yogi-berra-rings-warhol-pollock/story?id=100115548 URL #935 Response: 200; URL: https://www.nbcnews.com/news/latino/mexican-farmers-take-over-airport-governor-cargill-rcna89606 URL #936 Response: 200; URL: https://www.cnn.com/2023/06/15/us/los-angeles-migrants-bus-texas/index.html URL #937 Response: 200; URL: https://www.wired.com/story/obesity-drugs-researcher-interview-ozempic-wegovy/ URL #938 Response: 200; URL: https://www.usatoday.com/story/news/nation/2023/06/13/trump-arraignment-latest-bidentrump-election-poll-5-things-podcast/70316272007/ URL #939 Response: 200; URL: https://www.businessinsider.com/personal-finance/best-mortgage-refinance-rates-today-friday-june-16-2023-6 URL #940 Response: 200; URL: https://abcnews.go.com/International/wireStory/time-oscar-winner-glenda-jackson-mixed-acting-politics-100101078 URL #941 Response: 200; URL: https://www.foxnews.com/media/abba-star-weighs-altering-art-books-music-modern-audiences-leave-them-as-they-are URL #942 Response: 200; URL: https://abcnews.go.com/US/wireStory/participants-trumps-jan-6-rally-push-false-election-100162316 URL #943 Response: 200; URL: https://abcnews.go.com/International/wireStory/greece-90-migrants-rescued-us-flagged-yacht-distress-100006737 URL #944 Response: 200; URL: https://ftw.usatoday.com/article/athletics-vs-brewers-player-props-today-esteury-ruiz-june-11 URL #945 Response: 200; URL: https://www.nbcnews.com/news/us-news/jayland-walker-family-sues-officers-city-akron-excessive-force-nearly-rcna89783 URL #946 Response: 200; URL: https://abcnews.go.com/US/wireStory/theodore-ted-kaczynski-unabomber-died-federal-prison-99985171 URL #947 Response: 200; URL: https://abcnews.go.com/International/wireStory/mexico-primary-candidate-proposes-central-role-presidents-son-100212804 URL #948 Response: 200; URL: https://abcnews.go.com/Technology/wireStory/popular-low-treatment-safe-men-heart-disease-doctors-100145198 URL #949 Response: 200; URL: https://abcnews.go.com/International/wireStory/pastors-find-role-ministering-young-men-swept-el-100139042 URL #950 Response: 200; URL: https://abcnews.go.com/Business/wireStory/illumina-ceo-resigns-amid-pressure-activist-investor-carl-99996404 URL #951 Response: 200; URL: https://dolphinswire.usatoday.com/2023/06/13/dolphins-rookies-special-olympics-flag-football/ URL #952 Response: 200; URL: https://www.nbcnews.com/politics/donald-trump/e-jean-carrolls-defamation-trial-trump-set-jan-2024-rcna89615 URL #953 Response: 200; URL: https://www.nbcnews.com/meet-the-press/meetthepressblog/north-dakota-senators-back-gov-doug-burgum-president-rcna89122 URL #954 Response: 200; URL: https://www.breitbart.com/europe/2023/06/13/biden-administration-set-to-supply-depleted-uranium-rounds-to-ukraine-report/ URL #955 Response: 200; URL: https://www.buzzfeed.com/abbykass/genius-products-under-10 URL #956 Response: 200; URL: https://abcnews.go.com/Politics/pentagon-papers-whistleblower-daniel-ellsberg-dead-92/story?id=100149179 URL #957 Response: 200; URL: https://commanderswire.usatoday.com/2023/06/17/2024-nfl-draft-washington-commanders-land-left-tack ...
# ^^^Parse not successful^^^
# URL #993 Response: 200; URL: https://www.usatoday.com/story/life/health-wellness/2023/06/13/russell-okung-weight-loss-40-day-water-fast/70314293007/ URL #994 Response: 200; URL: https://www.nbcnews.com/health/health-news/nonalcoholic-fatty-liver-disease-rates-are-soaring-know-rcna89623 URL #995 Response: 200; URL: https://www.buzzfeed.com/melanie_aman/cheap-products-bring-joy-an URL #996 Response: 200; URL: https://www.businessinsider.com/personal-finance/best-mortgage-refinance-rates-today-tuesday-june-13-2023-6 URL #997 Response: 200; URL: https://www.buzzfeed.com/emmalord9/products-cute-enchanted URL #998 Response: 200; URL: https://www.usatoday.com/story/sports/golf/2023/06/16/us-open-live-leaderboard-second-round-updates-highlights-scores/70328437007/ URL #999 Response: 200; URL: https://aggieswire.usatoday.com/lists/texas-am-footballs-2024-schedule-reveal-how-will-things-shake-out/ URL #1000 Response: 200; URL: https://abcnews.go.com/US/wireStory/iga-swiatek-beats-karolina-muchova-win-3rd-french-99984207 URL #1001 Response: 200; URL: https://ftw.usatoday.com/article/cardinals-vs-mets-player-props-today-nolan-gorman-june-18 URL #1002 Response: 200; URL: https://abcnews.go.com/US/wireStory/north-carolina-governor-signs-sports-horse-racing-betting-100073353 URL #1003 Response: 200; URL: https://www.usatoday.com/story/news/nation/2023/06/12/little-caesars-shooting-arizona-employee-dead/70312639007/ URL #1004 Response: 200; URL: https://abcnews.go.com/Business/wireStory/week-business-100004782 URL #1005 Response: 200; URL: https://abcnews.go.com/International/wireStory/death-2-americans-mexico-resort-hotel-room-now-100129610 URL #1006 Response: 200; URL: https://www.breitbart.com/entertainment/2023/06/11/ana-navarro-posts-racist-comment-on-mar-a-lago-on-twitter-white-ppl/ URL #1007 Response: 200; URL: https://abcnews.go.com/US/wireStory/kamau-charismatic-iconic-african-lion-californias-sacramento-zoo-100184182 URL #1008 Response: 200; URL: https://www.businessinsider.com/goldman-sachs-david-solomon-partners-revolt-2023-6 URL #1009 Response: 200; URL: https://ftw.usatoday.com/2023/06/stephen-a-smith-ja-morant-meme-reaction-first-take URL #1010 Response: 200; URL: https://www.foxnews.com/entertainment/kristin-davis-shed-tears-ridiculed-relentlessly-fillers URL #1011 Response: 200; URL: https://chiefswire.usatoday.com/lists/kansas-city-chiefs-players-to-watch-mandatory-minicamp-charles-omenihu-wanya-morris-rashee-rice-justyn-ross/ URL #1012 Response: 200; URL: https://abcnews.go.com/Business/wireStory/uk-unemployment-rate-edges-unexpectedly-number-work-hits-100030806 URL #1013 Response: 200; URL: https://brownswire.usatoday.com/2023/06/15/browns-10th-most-cap-space-dead/ URL #1014 Response: 200; URL: https://bullswire.usatoday.com/2023/06/18/chicago-bulls-urged-trade-demar-derozan-hes-walking/ URL #1015 Response: 200; URL: https://ftw.usatoday.com/article/cardinals-vs-reds-player-props-today-nolan-arenado-june-11 URL #1016 Response: 200; URL: https://texanswire.usatoday.com/2023/06/13/j-j-watt-texans-phenomenal-talent-will-anderson/ URL #1017 Response: 200; URL: https://ftw.usatoday.com/2023/06/the-last-of-us-halloween-horror-nights URL #1018 Response: 200; URL: https://markets.businessinsider.com/news/stocks/stock-market-ai-boom-tech-stocks-dot-com-bubble-burst-2023-6 URL #1019 Response: 200; URL: https://www.businessinsider.com/the-atlantic-orca-story-reactions-killer-whales-sadistic-jerks-2023-6 URL #1020 Response: 200; URL: https://ftw.usatoday.com/2023/06/video-from-fishing-boat-in-high-seas-causes-viewers-to-become-seasick URL #1021 Response: 200; URL: https://www.breitbart.com/clips/2023/06/17/nbcs-memoli-china-making-us-come-back-more-apologetically-pretty-clear-biden-wants-thaw-with-china-more-than-ccp-does/ URL #1022 Response: 200; URL: https://abcnews.go.com/Entertainment/wireStory/select-list-winners-2023-tony-awards-100001621 URL #1023 Response: 200; URL: https://www.usatoday.com/story/sports/nba/playoffs/2023/06/13 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-bdf77b84f155> in <module>
#      43         response = requests.get(url)
#      44         print(f'URL #{idx} Response: {response.status_code}; URL: {url} ', end='')
# ---> 45         time.sleep(5 + 10 * random.random())
#      46
#      47         # Check if the request was successful
#
# KeyboardInterrupt:

# %% [markdown]
# ### Send MySQL records to CSV

# %% [markdown]
# Use pandas to select all articles from the MySQL database where `article_text` is not missing

# %%
slct_tbl_full_df01 = pd.read_sql(
                                '''
                                SELECT * FROM news_articles
                                WHERE article_text IS NOT NULL
                                ''',
                                db_conn)

# %% [markdown]
# Send dataframe to CSV

# %%
slct_tbl_full_df01.to_csv(scraped_file_path01, index=False)

# %% [markdown]
# Display dataframe attributes and header

# %%
print(type(slct_tbl_full_df01))
print(slct_tbl_full_df01.shape)
display(slct_tbl_full_df01.head(11))
#display(slct_tbl_full_df01['article_text'][0])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (15440, 8)
#     text_id       source_name                                author  \
# 0         1    Breitbart News              Lucas Nolan, Lucas Nolan
# 1         2         USA Today  USA TODAY, Emily DeLetter, USA TODAY
# 2         3         USA Today     USA TODAY, Joy Ashford, USA TODAY
# 3         4  Business Insider                          Amanda Smith
# 4         5         USA Today                        Tar Heels Wire
# 5         6         USA Today                        Roll Tide Wire
# 6         7         USA Today                          Celtics Wire
# 7         8         USA Today                           Lebron Wire
# 8         9    Breitbart News                Sean Moran, Sean Moran
# 9        10               CNN                       Parija Kavilanz
# 10       11             MSNBC                         Zeeshan Aleem
#
#                                                 title  \
# 0   Nerd War!: Elon Musk and Mark Zuckerberg Agree...
# 1   Tito's launches 'Tito's in a Big Can,' an empt...
# 2   Search for missing actor Julian Sands continue...
# 3   It costs over $300,000 to raise a child. For l...
# 4   Four star running back picks Michigan State ov...
# 5   Alabama center Charles Bediako signs one-year ...
# 6   Ralph Sampson breaks down iconic Boston Celtic...
# 7   Cowherd: Lakers are delusional for wanting to ...
# 8   Democrat Bob Casey Meets with Soros Connected,...
# 9   Walgreens profit tumbles, slashes guidance ami...
# 10  The MAGA right is going all in on RFK Jr. That...
#
#                                                   url          publish_date  \
# 0   https://www.breitbart.com/tech/2023/06/22/nerd...  2023-06-22T13:06:40Z
# 1   https://www.usatoday.com/story/money/food/2023...  2023-06-21T17:37:40Z
# 2   https://www.usatoday.com/story/entertainment/c...  2023-06-20T17:36:09Z
# 3   https://www.businessinsider.com/personal-finan...  2023-06-22T21:05:44Z
# 4   https://tarheelswire.usatoday.com/2023/06/24/f...  2023-06-25T03:51:10Z
# 5   https://rolltidewire.usatoday.com/2023/06/23/a...  2023-06-23T21:29:24Z
# 6   https://celticswire.usatoday.com/2023/06/23/nb...  2023-06-23T11:00:41Z
# 7   https://lebronwire.usatoday.com/2023/06/29/cow...  2023-06-29T18:00:40Z
# 8   https://www.breitbart.com/politics/2023/06/22/...  2023-06-22T21:18:35Z
# 9   https://www.cnn.com/2023/06/27/business/walgre...  2023-06-27T15:05:02Z
# 10  https://www.msnbc.com/opinion/msnbc-opinion/ro...  2023-06-27T10:00:00Z
#
#                                          article_text  \
# 0   \nElon Musk and Mark Zuckerberg, two of the wo...
# 1   Have you ever wanted to own your very own keg ...
# 2   Over five months after Julian Sands went missi...
# 3   Our experts answer readers' investing question...
# 4   \n\n\n\n\n\n\n\n\n\n\n\n\n\nFour star running ...
# 5   \n\n\n\n\n\n\n\n\n\n\n\n\n\nAlabama center Cha...
# 6   \n\n\n\n\n\n\n\n\n\n\n\n\n\nRalph Sampson brea...
# 7   \n\n\n\n\n\n\n\n\n\n\n\n\n\nCowherd: Lakers ar...
# 8   \nSen. Bob Casey’s (D-PA) office met with a gr...
# 9   Walgreens Boots Alliance on Tuesday reported e...
# 10  Rolling Stone recently uncovered a juicy data ...
#
#                                               content
# 0   Elon Musk and Mark Zuckerberg, two of the worl...
# 1   Have you ever wanted to own your very own keg ...
# 2   Over five months after Julian Sandswent missin...
# 3   Our experts answer readers' investing question...
# 4   Mack Brown and the UNC football program have b...
# 5   Alabama center Charles Bediako was signed to a...
# 6   It was one of the most memorable moments in NB...
# 7   One of the bright spots over the last two seas...
# 8   Sen. Bob Casey’s (D-PA) office met with a grou...
# 9   Walgreens Boots Alliance on Tuesday reported e...
# 10  Rolling Stone recently uncovered a juicy data ...

# %% [markdown]
# ### Commit changes and close cursor and connection instances

# %% [markdown]
# This step is integral to committing any remaining MySQL calls, as well as releasing the connection.

# %%
# Commit the changes to the database
db_conn.commit()

# Close the cursor and database connection
cursor.close()
db_conn.close()
